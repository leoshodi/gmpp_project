# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import Config

# %%
import yaml
def import_config(filepath):
  with open(filepath, 'r') as file:
    config = yaml.safe_load(file)
  return config

# %%
config = import_config('drive/MyDrive/Colab Notebooks/Data Science Coaching Resources/config.yaml')
config
# Out:
# {'test_prop': 0.2}

# %% [markdown]
# Import Data

# %%
data = pd.read_csv(file_name)#'drive/MyDrive/Colab Notebooks/Data Science Coaching Resources/dummy_data.csv'
#put file_name in config

# %%
def impute_missing_values(data, vals):
  return data

# %%
def feature_engineering(data):
  data = impute_missing_values(data)
  return data

# %% [markdown]
# Model Training

# %%
def fit_model(x_data, y_data):
  return model

# %% [markdown]
# Feature Selection

# %%
def get_best_features(model):
  return features

# %% [markdown]
# Hyperparameter Tuning

# %%
def tune_hyperparameters(data):
  return best_params

# %% [markdown]
# Final Model

# %%
def fit_model(x_data, y_data):
  return model

# %% [markdown]
# Model Performance

# %%
def evaluate_model(model, x_data, y_data):
  pass

# %% [markdown]
# Final Model Pipeline

# %%
def model_pipeline(run_id, import_folder):
  data = import_data
  data = impute_missing_values(data)
  data = feature_engineering(data)
  x_train, y_train, x_val, y_val = split_data(data)
  initial_model = fit_model(x_train, y_train)
  best_features = get_best_features(model)
  best_params = tune_hyperparameters()
  final_model = fit_model(x_data, y_data)
  evaluate_model(model, x_data, y_data)
  return model_data, model_object
